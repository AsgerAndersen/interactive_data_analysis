# %%
import pandas as pd
import scipy as scp

# %%
n = 2000
n_users = 20
users = range(0,n_users)

# %%
#Laaaaangsom!
def one_user(user, times) :
    return pd.concat([pd.DataFrame(targets(user,time)) for time in times], ignore_index=True)

# %%
def targets(user,timestamp) :
    m = scp.random.choice([0,1,2,3],p=[3/8,3/8,1/8,1/8])
    diffs = scp.random.choice([1,2,3,4],size=m,p=[10/16,4/16,1/16,1/16])
    if (scp.random.binomial(1,0.5) == 1) :
        targets = scp.mod((user + diffs), n_users)
    else :
        targets = scp.mod((user - diffs), n_users)
    signals = scp.random.choice([-100,-95,-90,-80,-70,-50,-10,-1],size=m)
    stamps = scp.repeat([timestamp],m)
    user = scp.repeat([user],m)
    return {'user_1':list(user),'timestamp': list(stamps), 'user_2':list(targets), 'signal':signals}

# %%
def all_users(users) :
    l = []
    for u in users :
        l.append(one_user(u, (scp.arange(0,n))*300))
    return pd.concat(l)

# %%
data = all_users(users)

# %%
data.shape
# Out:
# (40173, 4)

# %%
data.to_csv('simulated_data.csv')

# %%
data.head(30)
# Out:
#     signal  timestamp  user_1  user_2
# 0      -50        0.0     0.0     1.0
# 1      -70      300.0     0.0    19.0
# 2     -100      600.0     0.0    19.0
# 3     -100      600.0     0.0    19.0
# 4      -80      600.0     0.0    19.0
# 5      -95     2100.0     0.0    18.0
# 6      -95     2400.0     0.0     1.0
# 7      -70     2400.0     0.0     1.0
# 8       -1     3000.0     0.0    19.0
# 9      -10     3000.0     0.0    16.0
# 10     -50     3000.0     0.0    19.0
# 11    -100     3300.0     0.0    17.0
# 12     -10     3600.0     0.0    19.0
# 13     -80     4500.0     0.0    19.0
# 14     -70     4500.0     0.0    19.0
# 15     -95     4800.0     0.0    19.0
# 16     -50     4800.0     0.0    19.0
# 17     -70     4800.0     0.0    18.0
# 18     -50     5100.0     0.0    17.0
# 19     -90     5400.0     0.0    19.0
# 20     -70     6000.0     0.0    19.0
# 21     -80     6300.0     0.0     3.0
# 22     -80     6300.0     0.0     1.0
# 23     -95     6600.0     0.0    19.0
# 24    -100     6900.0     0.0     1.0
# 25      -1     7500.0     0.0     1.0
# 26    -100     7800.0     0.0     2.0
# 27     -10     7800.0     0.0     3.0
# 28     -10     7800.0     0.0     2.0
# 29    -100     8100.0     0.0    18.0
